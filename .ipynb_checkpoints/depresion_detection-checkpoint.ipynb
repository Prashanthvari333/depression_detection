# %% [raw]
# #Installations
# !pip install pandas
# !pip install scikit-learn
# !pip install matplotlib
# !pip install seaborn

# %%
#Import neccessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import VotingClassifier
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
# Load the dataset into a DataFrame
df = pd.read_csv('./post natal data.csv')

# %%
# Display the first few rows of the DataFrame
df.head()
# Out:
#          Timestamp    Age Feeling sad or Tearful  \
# 0  6/14/2022 20:02  35-40                    Yes
# 1  6/14/2022 20:03  40-45                    Yes
# 2  6/14/2022 20:04  35-40                    Yes
# 3  6/14/2022 20:05  35-40                    Yes
# 4  6/14/2022 20:06  40-45                    Yes
#
#   Irritable towards baby & partner Trouble sleeping at night  \
# 0                              Yes   Two or more days a week
# 1                               No                        No
# 2                               No                       Yes
# 3                              Yes                       Yes
# 4                               No   Two or more days a week
#
#   Problems concentrating or making decision Overeating or loss of appetite  \
# 0                                       Yes                            Yes
# 1                                       Yes                            Yes
# 2                                       Yes                            Yes
# 3                                       Yes                             No
# 4                                       Yes                             No
#
#   Feeling anxious Feeling of guilt Problems of bonding with baby  \
# 0             Yes               No                           Yes
# 1              No              Yes                           Yes
# 2             Yes               No                     Sometimes
# 3             Yes            Maybe                            No
# 4             Yes               No                           Yes
#
#   Suicide attempt
# 0             Yes
# 1              No
# 2              No
# 3              No
# 4              No

# %%
df.describe()
# Out:
#               Timestamp    Age Feeling sad or Tearful  \
# count              1503   1503                   1503
# unique               90      5                      3
# top     6/15/2022 22:24  40-45                    Yes
# freq                 51    364                    536
#
#        Irritable towards baby & partner Trouble sleeping at night  \
# count                              1497                      1503
# unique                                3                         3
# top                                 Yes   Two or more days a week
# freq                                555                       640
#
#        Problems concentrating or making decision  \
# count                                       1491
# unique                                         3
# top                                           No
# freq                                         583
#
#        Overeating or loss of appetite Feeling anxious Feeling of guilt  \
# count                            1503            1503             1494
# unique                              3               2                3
# top                                No             Yes               No
# freq                              841             980              624
#
#        Problems of bonding with baby Suicide attempt
# count                           1503            1503
# unique                             3               3
# top                               No              No
# freq                             557             709

# %%
df.isnull()
# Out:
#       Timestamp    Age  Feeling sad or Tearful  \
# 0         False  False                   False
# 1         False  False                   False
# 2         False  False                   False
# 3         False  False                   False
# 4         False  False                   False
# ...         ...    ...                     ...
# 1498      False  False                   False
# 1499      False  False                   False
# 1500      False  False                   False
# 1501      False  False                   False
# 1502      False  False                   False
#
#       Irritable towards baby & partner  Trouble sleeping at night  \
# 0                                False                      False
# 1                                False                      False
# 2                                False                      False
# 3                                False                      False
# 4                                False                      False
# ...                                ...                        ...
# 1498                             False                      False
# 1499                             False                      False
# 1500                             False                      False
# 1501                             False                      False
# 1502                             False                      False
#
#       Problems concentrating or making decision  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ...                                         ...
# 1498                                      False
# 1499                                      False
# 1500                                      False
# 1501                                      False
# 1502                                      False
#
#       Overeating or loss of appetite  Feeling anxious  Feeling of guilt  \
# 0                              False            False             False
# 1                              False            False             False
# 2                              False            False             False
# 3                              False            False             False
# 4                              False            False             False
# ...                              ...              ...               ...
# 1498                           False            False             False
# 1499                           False            False             False
# 1500                           False            False             False
# 1501                           False            False             False
# 1502                           False            False             False
#
#       Problems of bonding with baby  Suicide attempt
# 0                             False            False
# 1                             False            False
# 2                             False            False
# 3                             False            False
# 4                             False            False
# ...                             ...              ...
# 1498                          False            False
# 1499                          False            False
# 1500                          False            False
# 1501                          False            False
# 1502                          False            False
#
# [1503 rows x 11 columns]

# %%
df.isnull().count()
# Out:
# Timestamp                                    1503
# Age                                          1503
# Feeling sad or Tearful                       1503
# Irritable towards baby & partner             1503
# Trouble sleeping at night                    1503
# Problems concentrating or making decision    1503
# Overeating or loss of appetite               1503
# Feeling anxious                              1503
# Feeling of guilt                             1503
# Problems of bonding with baby                1503
# Suicide attempt                              1503
# dtype: int64

# %%
column_names = list(df.columns)
print(column_names)
# Out:
# ['Timestamp', 'Age', 'Feeling sad or Tearful', 'Irritable towards baby & partner', 'Trouble sleeping at night', 'Problems concentrating or making decision', 'Overeating or loss of appetite', 'Feeling anxious', 'Feeling of guilt', 'Problems of bonding with baby', 'Suicide attempt']

# %%
df.dtypes
# Out:
# Timestamp                                    object
# Age                                          object
# Feeling sad or Tearful                       object
# Irritable towards baby & partner             object
# Trouble sleeping at night                    object
# Problems concentrating or making decision    object
# Overeating or loss of appetite               object
# Feeling anxious                              object
# Feeling of guilt                             object
# Problems of bonding with baby                object
# Suicide attempt                              object
# dtype: object

# %%
df.drop(columns=['Timestamp'],inplace=True) # Features (excluding 'Timestamp')

# %%
# Get non-numeric columns
non_numeric_columns = df.select_dtypes(exclude=['number']).columns
print("Non-Numeric Columns:", non_numeric_columns)
# Out:
# Non-Numeric Columns: Index(['Age', 'Feeling sad or Tearful', 'Irritable towards baby & partner',
#        'Trouble sleeping at night',
#        'Problems concentrating or making decision',
#        'Overeating or loss of appetite', 'Feeling anxious', 'Feeling of guilt',
#        'Problems of bonding with baby', 'Suicide attempt'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
# Instantiate LabelEncoder
label_encoder = LabelEncoder()

# Convert non-numeric columns to numeric using label encoding
non_numeric_columns = ['Age', 'Feeling sad or Tearful', 'Irritable towards baby & partner',
                       'Trouble sleeping at night', 'Problems concentrating or making decision',
                       'Overeating or loss of appetite', 'Feeling anxious', 'Feeling of guilt',
                       'Problems of bonding with baby', 'Suicide attempt']

for column in non_numeric_columns:
    df[column] = label_encoder.fit_transform(df[column])

# Now, the non-numeric columns are converted to numeric using label encoding
df.head()
# Out:
#    Age  Feeling sad or Tearful  Irritable towards baby & partner  \
# 0    2                       2                                 2
# 1    3                       2                                 0
# 2    2                       2                                 0
# 3    2                       2                                 2
# 4    3                       2                                 0
#
#    Trouble sleeping at night  Problems concentrating or making decision  \
# 0                          1                                          2
# 1                          0                                          2
# 2                          2                                          2
# 3                          2                                          2
# 4                          1                                          2
#
#    Overeating or loss of appetite  Feeling anxious  Feeling of guilt  \
# 0                               2                1                 1
# 1                               2                0                 2
# 2                               2                1                 1
# 3                               0                1                 0
# 4                               0                1                 1
#
#    Problems of bonding with baby  Suicide attempt
# 0                              2                2
# 1                              2                0
# 2                              1                0
# 3                              0                0
# 4                              2                0

# %%
df.corr()
# Out:
#                                                 Age  Feeling sad or Tearful  \
# Age                                        1.000000               -0.007180
# Feeling sad or Tearful                    -0.007180                1.000000
# Irritable towards baby & partner           0.029192               -0.207556
# Trouble sleeping at night                 -0.078397               -0.117364
# Problems concentrating or making decision  0.021002                0.059546
# Overeating or loss of appetite            -0.158305                0.360815
# Feeling anxious                            0.056179               -0.039628
# Feeling of guilt                          -0.072091               -0.196611
# Problems of bonding with baby             -0.001325                0.166051
# Suicide attempt                           -0.074603               -0.225143
#
#                                            Irritable towards baby & partner  \
# Age                                                                0.029192
# Feeling sad or Tearful                                            -0.207556
# Irritable towards baby & partner                                   1.000000
# Trouble sleeping at night                                         -0.041772
# Problems concentrating or making decision                          0.135745
# Overeating or loss of appetite                                    -0.020513
# Feeling anxious                                                    0.039082
# Feeling of guilt                                                   0.082534
# Problems of bonding with baby                                     -0.077451
# Suicide attempt                                                    0.271101
#
#                                            Trouble sleeping at night  \
# Age                                                        -0.078397
# Feeling sad or Tearful                                     -0.117364
# Irritable towards baby & partner                           -0.041772
# Trouble sleeping at night                                   1.000000
# Problems concentrating or making decision                  -0.108746
# Overeating or loss of appetite                              0.025543
# Feeling anxious                                            -0.120967
# Feeling of guilt                                            0.108619
# Problems of bonding with baby                              -0.149777
# Suicide attempt                                             0.156737
#
#                                            Problems concentrating or making decision  \
# Age                                                                         0.021002
# Feeling sad or Tearful                                                      0.059546
# Irritable towards baby & partner                                            0.135745
# Trouble sleeping at night                                                  -0.108746
# Problems concentrating or making decision                                   1.000000
# Overeating or loss of appetite                                              0.022092
# Feeling anxious                                                             0.173079
# Feeling of guilt                                                            0.008410
# Problems of bonding with baby                                               0.294650
# Suicide attempt                                                             0.092960
#
#                                            Overeating or loss of appetite  \
# Age                                                             -0.158305
# Feeling sad or Tearful                                           0.360815
# Irritable towards baby & partner                                -0.020513
# Trouble sleeping at night                                        0.025543
# Problems concentrating or making decision                        0.022092
# Overeating or loss of appetite                                   1.000000
# Feeling anxious                                                 -0.151471
# Feeling of guilt                                                 0.148645
# Problems of bonding with baby                                    0.084874
# Suicide attempt                                                 -0.018513
#
#                                            Feeling anxious  Feeling of guilt  \
# Age                                               0.056179         -0.072091
# Feeling sad or Tearful                           -0.039628         -0.196611
# Irritable towards baby & partner                  0.039082          0.082534
# Trouble sleeping at night                        -0.120967          0.108619
# Problems concentrating or making decision         0.173079          0.008410
# Overeating or loss of appetite                   -0.151471          0.148645
# Feeling anxious                                   1.000000         -0.255358
# Feeling of guilt                                 -0.255358          1.000000
# Problems of bonding with baby                     0.226769         -0.159524
# Suicide attempt                                  -0.040325          0.265138
#
#                                            Problems of bonding with baby  \
# Age                                                            -0.001325
# Feeling sad or Tearful                                          0.166051
# Irritable towards baby & partner                               -0.077451
# Trouble sleeping at night                                      -0.149777
# Problems concentrating or making decision                       0.294650
# Overeating or loss of appetite                                  0.084874
# Feeling anxious                                                 0.226769
# Feeling of guilt                                               -0.159524
# Problems of bonding with baby                                   1.000000
# Suicide attempt                                                -0.037258
#
#                                            Suicide attempt
# Age                                              -0.074603
# Feeling sad or Tearful                           -0.225143
# Irritable towards baby & partner                  0.271101
# Trouble sleeping at night                         0.156737
# Problems concentrating or making decision         0.092960
# Overeating or loss of appetite                   -0.018513
# Feeling anxious                                  -0.040325
# Feeling of guilt                                  0.265138
# Problems of bonding with baby                    -0.037258
# Suicide attempt                                   1.000000

# %%
correlation_matrix = df.corr()
correlation_with_target = correlation_matrix['Feeling anxious'].abs().sort_values(ascending=False)

# %%
# Define features and target variable
X = df.drop(columns=['Feeling anxious'])  
y = df['Feeling anxious']  # Target variable

# %%
X.head()
# Out:
#    Age  Feeling sad or Tearful  Irritable towards baby & partner  \
# 0    2                       2                                 2
# 1    3                       2                                 0
# 2    2                       2                                 0
# 3    2                       2                                 2
# 4    3                       2                                 0
#
#    Trouble sleeping at night  Problems concentrating or making decision  \
# 0                          1                                          2
# 1                          0                                          2
# 2                          2                                          2
# 3                          2                                          2
# 4                          1                                          2
#
#    Overeating or loss of appetite  Feeling of guilt  \
# 0                               2                 1
# 1                               2                 2
# 2                               2                 1
# 3                               0                 0
# 4                               0                 1
#
#    Problems of bonding with baby  Suicide attempt
# 0                              2                2
# 1                              2                0
# 2                              1                0
# 3                              0                0
# 4                              2                0

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: Feeling anxious, dtype: int32

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
# SVM optimization using GridSearchCV
svm_param_grid = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf'],
    'gamma': ['scale', 'auto']
}

svm_classifier = SVC(probability=True)
grid_search_svm = GridSearchCV(svm_classifier, svm_param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search_svm.fit(X_train, y_train)

# Print the best parameters found for SVM
print("Best Parameters for SVM:", grid_search_svm.best_params_)
# Out:
# Best Parameters for SVM: {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}

# %%
# Fit a Random Forest model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Get feature importances
feature_importances = rf_model.feature_importances_

# %%
from sklearn.feature_selection import SelectKBest, chi2

# Select top k features based on chi-square test
selector = SelectKBest(score_func=chi2, k=5)
X_new = selector.fit_transform(X_train, y_train)

# %%
from sklearn.feature_selection import RFE

# Initialize model for RFE
estimator = RandomForestClassifier(n_estimators=100, random_state=42)

# Initialize RFE
rfe = RFE(estimator, n_features_to_select=5)

# Fit RFE
rfe.fit(X_train, y_train)

# Selected features
selected_features = X_train.columns[rfe.support_]

# %%
from sklearn.linear_model import LogisticRegression

# Initialize Logistic Regression model with L1 regularization
logreg = LogisticRegression(penalty='l1', solver='liblinear')

# Fit the model
logreg.fit(X_train, y_train)

# Get the coefficients
coefficients = logreg.coef_

# %%
# Drop irrelevant features
#df_filtered = df.drop(columns=['irrelevant_feature1', 'irrelevant_feature2'])

# %%
# Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
# Create a list of tuples containing classifier names and their corresponding instances
classifiers = [
    ('SVM', grid_search_svm.best_estimator_),  # Use the best SVM model from GridSearchCV
    ('Random Forest', rf_classifier)
]

# %%
# Train each classifier and evaluate its performance
for clf_name, clf in classifiers:
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f'{clf_name} Accuracy: {accuracy}')
# Out:
# SVM Accuracy: 0.9735099337748344
# Random Forest Accuracy: 0.9867549668874173

# %%
# Create a VotingClassifier with SVM and Random Forest
voting_clf = VotingClassifier(estimators=classifiers, voting='soft')

# %%
# Train the VotingClassifier
voting_clf.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('SVM', SVC(C=100, probability=True)),
#                              ('Random Forest',
#                               RandomForestClassifier(random_state=42))],
#                  voting='soft')

# %%
# Predictions using the ensemble model
ensemble_pred = voting_clf.predict(X_test)

# %%
# Evaluate the ensemble model
ensemble_accuracy = accuracy_score(y_test, ensemble_pred)

# %%
print(f'Ensemble Accuracy: {ensemble_accuracy}')
# Out:
# Ensemble Accuracy: 0.9735099337748344

# %%
import matplotlib.pyplot as plt

# Plot bar plot for the 'Age' feature
plt.bar(df['Age'].value_counts().index, df['Age'].value_counts().values, color='skyblue', edgecolor='black')
plt.xlabel('Age Category')
plt.ylabel('Frequency')
plt.title('Distribution of Age Categories')
plt.show()

# %%
import seaborn as sns

# Create a pairplot
sns.pairplot(df)
plt.show()

# %%
# Create boxplots for each feature
df.boxplot(figsize=(10,6))
plt.xticks(rotation=45)
plt.title('Boxplot of Features')
plt.show()

# %%
# Create countplots for categorical features
categorical_features = ['Feeling sad or Tearful', 'Irritable towards baby & partner', 'Trouble sleeping at night', 'Feeling anxious', 'Feeling of guilt', 'Problems of bonding with baby', 'Suicide attempt']
for feature in categorical_features:
    sns.countplot(x=feature, data=df)
    plt.title(f'Countplot of {feature}')
    plt.show()

# %%
# Create a heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
from sklearn.metrics import RocCurveDisplay
import matplotlib.pyplot as plt
svc_disp = RocCurveDisplay.from_estimator(grid_search_svm.best_estimator_, X_test, y_test)
rfc_disp = RocCurveDisplay.from_estimator(rf_classifier, X_test, y_test, ax=svc_disp.ax_)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
